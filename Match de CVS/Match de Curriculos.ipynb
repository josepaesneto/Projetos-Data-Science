# %% [markdown]
# ## **DATA SCIENCE PARA MATCH DE CURRÍCULOS COM VAGAS DE EMPREGO**

# %% [markdown]
# ---
# ### **Importação dos CVs**

# %%
import pdfplumber
import nltk

# %%
arquivoPDF = pdfplumber.open('CV.pdf')

primeira_pagina = arquivoPDF.pages[0]


textoCRU = primeira_pagina.extract_text()
textoCRU
# Out:
# ' \nEMAIL \nJosé Paes da Costa Neto \njnetopc@gmail.com \nTELEFONES \n(79) 981311901 \n(79) 999175999  Cientista de Dados, Formação em Matemática Aplicada, Experiência na área \nENDEREÇO  LinkedIn  de Machine Learning. \nAracaju/SE  \n \nLINKEDIN \nOBJETIVO:  Atuar como Cientista de Dados \nhttps://www.linkedin.com/in/josé-paes-da-\ncosta-neto \nGitHub \nhttps://github.com/josepaesneto \n \n  EXPERIÊNCIA \nAnalista de Sistemas \nRede Cuidar do   Responsável pela implementação e suporte do Sistema E-SUS e do banco de dados durante a                  \nestado da Paraíba  caravana da Rede Cuidar do estado da Paraíba.  \n07.2019 - Voluntario \n \nAuxiliar de \nLotado no setor de TI, responsável pela Rede e pelo Banco de dados. Realizou projeto de  \nCartório \nConstrução do banco de dados com os registros dos Imóveis e protestos de títulos que  \nPrimeiro Oficio de Socorro \nestavam cadastrados na empresa na forma física. \n08.2014 – 11.2014 \n \n  FORMAÇÃO \nUFPB – Universidade Federal   Mestrado em Modelagem Computacional \nda Paraíba (PB)  Período 2017 – Interrompido  \nUFS – Universidade Federal de Sergipe  Matemática Aplicada e Computacional \n(SE)  Período 2013 – 2017  \nIDIOMAS  PROJETOS E EXTENSÕES \nPortuguês     \n▪  Iniciação Científica: PIBIC – Projeto de Construção de Imagens Panorâmicas Utilizando \nInglês    Machine Learning. \nEspanhol   \n   \n  TREINAMENTOS \nINFORMÁTICA \n  ▪  Imersão FLAI em Projetos de Data Science – FLAI Inteligência Artificial \n▪  Python Avançado  ▪  Jornada do Python – Hashtag Treinamentos \n▪  Jornada do Excel – Hashtag Treinamentos  \n▪  Excel Avançado  ▪  Dashboards com Power BI – Mamba Treinamentos. \n▪  Power BI Intermediário \n \n▪  Machine Learning Intermediário \n▪  Estatística Avançada \n▪  Big Data Intermediário \n▪  R Intermediário \n▪  SQL Intermediário \n '

# %%
arquivoPDF.metadata
# Out:
# {'Author': 'Neto Paes',
#  'Creator': 'Microsoft® Word 2019',
#  'CreationDate': "D:20211215223554-03'00'",
#  'ModDate': "D:20211215223554-03'00'",
#  'Producer': 'Microsoft® Word 2019'}

# %%
arquivoPDF.hyperlinks
# Out:
# []

# %%
print(textoCRU)
# Out:
#
# EMAIL
# José Paes da Costa Neto
# jnetopc@gmail.com
# TELEFONES
# (79) 981311901
# (79) 999175999  Cientista de Dados, Formação em Matemática Aplicada, Experiência na área
# ENDEREÇO  LinkedIn  de Machine Learning.
# Aracaju/SE
#
# LINKEDIN
# OBJETIVO:  Atuar como Cientista de Dados
# https://www.linkedin.com/in/josé-paes-da-
# costa-neto
# GitHub
# https://github.com/josepaesneto
#
#   EXPERIÊNCIA
# Analista de Sistemas
# Rede Cuidar do   Responsável pela implementação e suporte do Sistema E-SUS e do banco de dados durante a
# estado da Paraíba  caravana da Rede Cuidar do estado da Paraíba.
# 07.2019 - Voluntario
#
# Auxiliar de
# Lotado no setor de TI, responsável pela Rede e pelo Banco de dados. Realizou projeto de
# Cartório
# Construção do banco de dados com os registros dos Imóveis e protestos de títulos que
# Primeiro Oficio de Socorro
# estavam cadastrados na empresa na forma física.
# 08.2014 – 11.2014
#
#   FORMAÇÃO
# UFPB – Universidade Federal   Mestrado em Modelagem Computacional
# da Paraíba (PB)  Período 2017 – Interrompido
# UFS – Universidade Federal de Sergipe  Matemática Aplicada e Computacional
# (SE)  Período 2013 – 2017
# IDIOMAS  PROJETOS E EXTENSÕES
# Português
# ▪  Iniciação Científica: PIBIC – Projeto de Construção de Imagens Panorâmicas Utilizando
# Inglês    Machine Learning.
# Espanhol
#
#   TREINAMENTOS
# INFORMÁTICA
#   ▪  Imersão FLAI em Projetos de Data Science – FLAI Inteligência Artificial
# ▪  Python Avançado  ▪  Jornada do Python – Hashtag Treinamentos
# ▪  Jornada do Excel – Hashtag Treinamentos
# ▪  Excel Avançado  ▪  Dashboards com Power BI – Mamba Treinamentos.
# ▪  Power BI Intermediário
#
# ▪  Machine Learning Intermediário
# ▪  Estatística Avançada
# ▪  Big Data Intermediário
# ▪  R Intermediário
# ▪  SQL Intermediário

# %% [markdown]
# ---
# ## **Pré-processamento de Texto**

# %%
# A função word_tokenize() quebra o texto em palavras individuais.
nltk.download('punkt')
lista_de_palavras = nltk.tokenize.word_tokenize(textoCRU)
lista_de_palavras
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jneto\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['EMAIL',
#  'José',
#  'Paes',
#  'da',
#  'Costa',
#  'Neto',
#  'jnetopc',
#  '@',
#  'gmail.com',
#  'TELEFONES',
#  '(',
#  '79',
#  ')',
#  '981311901',
#  '(',
#  '79',
#  ')',
#  '999175999',
#  'Cientista',
#  'de',
#  'Dados',
#  ',',
#  'Formação',
#  'em',
#  'Matemática',
#  'Aplicada',
#  ',',
#  'Experiência',
#  'na',
#  'área',
#  'ENDEREÇO',
#  'LinkedIn',
#  'de',
#  'Machine',
#  'Learning',
#  '.',
#  'Aracaju/SE',
#  'LINKEDIN',
#  'OBJETIVO',
#  ':',
#  'Atuar',
#  'como',
#  'Cientista',
#  'de',
#  'Dados',
#  'https',
#  ':',
#  '//www.linkedin.com/in/josé-paes-da-',
#  'costa-neto',
#  'GitHub',
#  'https',
#  ':',
#  '//github.com/josepaesneto',
#  'EXPERIÊNCIA',
#  'Analista',
#  'de',
#  'Sistemas',
#  'Rede',
#  'Cuidar',
#  'do',
#  'Responsável',
#  'pela',
#  'implementação',
#  'e',
#  'suporte',
#  'do',
#  'Sistema',
#  'E-SUS',
#  'e',
#  'do',
#  'banco',
#  'de',
#  'dados',
#  'durante',
#  'a',
#  'estado',
#  'da',
#  'Paraíba',
#  'caravana',
#  'da',
#  'Rede',
#  'Cuidar',
#  'do',
#  'estado',
#  'da',
#  'Paraíba',
#  '.',
#  '07.2019',
#  '-',
#  'Voluntario',
#  'Auxiliar',
#  'de',
#  'Lotado',
#  'no',
#  'setor',
#  'de',
#  'TI',
#  ',',
#  'responsável',
#  'pela',
#  'Rede',
#  'e',
#  'pelo',
#  'Banco',
#  'de',
#  'dados',
#  '.',
#  'Realizou',
#  'projeto',
#  'de',
#  'Cartório',
#  'Construção',
#  'do',
#  'banco',
#  'de',
#  'dados',
#  'com',
#  'os',
#  'registros',
#  'dos',
#  'Imóveis',
#  'e',
#  'protestos',
#  'de',
#  'títulos',
#  'que',
#  'Primeiro',
#  'Oficio',
#  'de',
#  'Socorro',
#  'estavam',
#  'cadastrados',
#  'na',
#  'empresa',
#  'na',
#  'forma',
#  'física',
#  '.',
#  '08.2014',
#  '–',
#  '11.2014',
#  'FORMAÇÃO',
#  'UFPB',
#  '–',
#  'Universidade',
#  'Federal',
#  'Mestrado',
#  'em',
#  'Modelagem',
#  'Computacional',
#  'da',
#  'Paraíba',
#  '(',
#  'PB',
#  ')',
#  'Período',
#  '2017',
#  '–',
#  'Interrompido',
#  'UFS',
#  '–',
#  'Universidade',
#  'Federal',
#  'de',
#  'Sergipe',
#  'Matemática',
#  'Aplicada',
#  'e',
#  'Computacional',
#  '(',
#  'SE',
#  ')',
#  'Período',
#  '2013',
#  '–',
#  '2017',
#  'IDIOMAS',
#  'PROJETOS',
#  'E',
#  'EXTENSÕES',
#  'Português',
#  '▪',
#  'Iniciação',
#  'Científica',
#  ':',
#  'PIBIC',
#  '–',
#  'Projeto',
#  'de',
#  'Construção',
#  'de',
#  'Imagens',
#  'Panorâmicas',
#  'Utilizando',
#  'Inglês',
#  'Machine',
#  'Learning',
#  '.',
#  'Espanhol',
#  'TREINAMENTOS',
#  'INFORMÁTICA',
#  '▪',
#  'Imersão',
#  'FLAI',
#  'em',
#  'Projetos',
#  'de',
#  'Data',
#  'Science',
#  '–',
#  'FLAI',
#  'Inteligência',
#  'Artificial',
#  '▪',
#  'Python',
#  'Avançado',
#  '▪',
#  'Jornada',
#  'do',
#  'Python',
#  '–',
#  'Hashtag',
#  'Treinamentos',
#  '▪',
#  'Jornada',
#  'do',
#  'Excel',
#  '–',
#  'Hashtag',
#  'Treinamentos',
#  '▪',
#  'Excel',
#  'Avançado',
#  '▪',
#  'Dashboards',
#  'com',
#  'Power',
#  'BI',
#  '–',
#  'Mamba',
#  'Treinamentos',
#  '.',
#  '▪',
#  'Power',
#  'BI',
#  'Intermediário',
#  '▪',
#  'Machine',
#  'Learning',
#  'Intermediário',
#  '▪',
#  'Estatística',
#  'Avançada',
#  '▪',
#  'Big',
#  'Data',
#  'Intermediário',
#  '▪',
#  'R',
#  'Intermediário',
#  '▪',
#  'SQL',
#  'Intermediário']

# %%
# Padronizando as palavras em lowercase (apenas letras minúsculas)
lista_de_palavras = [palavra.lower() for palavra in lista_de_palavras]
lista_de_palavras
# Out:
# ['email',
#  'josé',
#  'paes',
#  'da',
#  'costa',
#  'neto',
#  'jnetopc',
#  '@',
#  'gmail.com',
#  'telefones',
#  '(',
#  '79',
#  ')',
#  '981311901',
#  '(',
#  '79',
#  ')',
#  '999175999',
#  'cientista',
#  'de',
#  'dados',
#  ',',
#  'formação',
#  'em',
#  'matemática',
#  'aplicada',
#  ',',
#  'experiência',
#  'na',
#  'área',
#  'endereço',
#  'linkedin',
#  'de',
#  'machine',
#  'learning',
#  '.',
#  'aracaju/se',
#  'linkedin',
#  'objetivo',
#  ':',
#  'atuar',
#  'como',
#  'cientista',
#  'de',
#  'dados',
#  'https',
#  ':',
#  '//www.linkedin.com/in/josé-paes-da-',
#  'costa-neto',
#  'github',
#  'https',
#  ':',
#  '//github.com/josepaesneto',
#  'experiência',
#  'analista',
#  'de',
#  'sistemas',
#  'rede',
#  'cuidar',
#  'do',
#  'responsável',
#  'pela',
#  'implementação',
#  'e',
#  'suporte',
#  'do',
#  'sistema',
#  'e-sus',
#  'e',
#  'do',
#  'banco',
#  'de',
#  'dados',
#  'durante',
#  'a',
#  'estado',
#  'da',
#  'paraíba',
#  'caravana',
#  'da',
#  'rede',
#  'cuidar',
#  'do',
#  'estado',
#  'da',
#  'paraíba',
#  '.',
#  '07.2019',
#  '-',
#  'voluntario',
#  'auxiliar',
#  'de',
#  'lotado',
#  'no',
#  'setor',
#  'de',
#  'ti',
#  ',',
#  'responsável',
#  'pela',
#  'rede',
#  'e',
#  'pelo',
#  'banco',
#  'de',
#  'dados',
#  '.',
#  'realizou',
#  'projeto',
#  'de',
#  'cartório',
#  'construção',
#  'do',
#  'banco',
#  'de',
#  'dados',
#  'com',
#  'os',
#  'registros',
#  'dos',
#  'imóveis',
#  'e',
#  'protestos',
#  'de',
#  'títulos',
#  'que',
#  'primeiro',
#  'oficio',
#  'de',
#  'socorro',
#  'estavam',
#  'cadastrados',
#  'na',
#  'empresa',
#  'na',
#  'forma',
#  'física',
#  '.',
#  '08.2014',
#  '–',
#  '11.2014',
#  'formação',
#  'ufpb',
#  '–',
#  'universidade',
#  'federal',
#  'mestrado',
#  'em',
#  'modelagem',
#  'computacional',
#  'da',
#  'paraíba',
#  '(',
#  'pb',
#  ')',
#  'período',
#  '2017',
#  '–',
#  'interrompido',
#  'ufs',
#  '–',
#  'universidade',
#  'federal',
#  'de',
#  'sergipe',
#  'matemática',
#  'aplicada',
#  'e',
#  'computacional',
#  '(',
#  'se',
#  ')',
#  'período',
#  '2013',
#  '–',
#  '2017',
#  'idiomas',
#  'projetos',
#  'e',
#  'extensões',
#  'português',
#  '▪',
#  'iniciação',
#  'científica',
#  ':',
#  'pibic',
#  '–',
#  'projeto',
#  'de',
#  'construção',
#  'de',
#  'imagens',
#  'panorâmicas',
#  'utilizando',
#  'inglês',
#  'machine',
#  'learning',
#  '.',
#  'espanhol',
#  'treinamentos',
#  'informática',
#  '▪',
#  'imersão',
#  'flai',
#  'em',
#  'projetos',
#  'de',
#  'data',
#  'science',
#  '–',
#  'flai',
#  'inteligência',
#  'artificial',
#  '▪',
#  'python',
#  'avançado',
#  '▪',
#  'jornada',
#  'do',
#  'python',
#  '–',
#  'hashtag',
#  'treinamentos',
#  '▪',
#  'jornada',
#  'do',
#  'excel',
#  '–',
#  'hashtag',
#  'treinamentos',
#  '▪',
#  'excel',
#  'avançado',
#  '▪',
#  'dashboards',
#  'com',
#  'power',
#  'bi',
#  '–',
#  'mamba',
#  'treinamentos',
#  '.',
#  '▪',
#  'power',
#  'bi',
#  'intermediário',
#  '▪',
#  'machine',
#  'learning',
#  'intermediário',
#  '▪',
#  'estatística',
#  'avançada',
#  '▪',
#  'big',
#  'data',
#  'intermediário',
#  '▪',
#  'r',
#  'intermediário',
#  '▪',
#  'sql',
#  'intermediário']

# %%
#Criando uma lista que contém pontuação que desejo remover
pontuacao = ['(',')',';',':','[',']',',']

# %%
#Criando uma lista de stop words "a", "de", "um"que não tem valor como palavra
nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('portuguese')
stop_words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jneto\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['de',
#  'a',
#  'o',
#  'que',
#  'e',
#  'é',
#  'do',
#  'da',
#  'em',
#  'um',
#  'para',
#  'com',
#  'não',
#  'uma',
#  'os',
#  'no',
#  'se',
#  'na',
#  'por',
#  'mais',
#  'as',
#  'dos',
#  'como',
#  'mas',
#  'ao',
#  'ele',
#  'das',
#  'à',
#  'seu',
#  'sua',
#  'ou',
#  'quando',
#  'muito',
#  'nos',
#  'já',
#  'eu',
#  'também',
#  'só',
#  'pelo',
#  'pela',
#  'até',
#  'isso',
#  'ela',
#  'entre',
#  'depois',
#  'sem',
#  'mesmo',
#  'aos',
#  'seus',
#  'quem',
#  'nas',
#  'me',
#  'esse',
#  'eles',
#  'você',
#  'essa',
#  'num',
#  'nem',
#  'suas',
#  'meu',
#  'às',
#  'minha',
#  'numa',
#  'pelos',
#  'elas',
#  'qual',
#  'nós',
#  'lhe',
#  'deles',
#  'essas',
#  'esses',
#  'pelas',
#  'este',
#  'dele',
#  'tu',
#  'te',
#  'vocês',
#  'vos',
#  'lhes',
#  'meus',
#  'minhas',
#  'teu',
#  'tua',
#  'teus',
#  'tuas',
#  'nosso',
#  'nossa',
#  'nossos',
#  'nossas',
#  'dela',
#  'delas',
#  'esta',
#  'estes',
#  'estas',
#  'aquele',
#  'aquela',
#  'aqueles',
#  'aquelas',
#  'isto',
#  'aquilo',
#  'estou',
#  'está',
#  'estamos',
#  'estão',
#  'estive',
#  'esteve',
#  'estivemos',
#  'estiveram',
#  'estava',
#  'estávamos',
#  'estavam',
#  'estivera',
#  'estivéramos',
#  'esteja',
#  'estejamos',
#  'estejam',
#  'estivesse',
#  'estivéssemos',
#  'estivessem',
#  'estiver',
#  'estivermos',
#  'estiverem',
#  'hei',
#  'há',
#  'havemos',
#  'hão',
#  'houve',
#  'houvemos',
#  'houveram',
#  'houvera',
#  'houvéramos',
#  'haja',
#  'hajamos',
#  'hajam',
#  'houvesse',
#  'houvéssemos',
#  'houvessem',
#  'houver',
#  'houvermos',
#  'houverem',
#  'houverei',
#  'houverá',
#  'houveremos',
#  'houverão',
#  'houveria',
#  'houveríamos',
#  'houveriam',
#  'sou',
#  'somos',
#  'são',
#  'era',
#  'éramos',
#  'eram',
#  'fui',
#  'foi',
#  'fomos',
#  'foram',
#  'fora',
#  'fôramos',
#  'seja',
#  'sejamos',
#  'sejam',
#  'fosse',
#  'fôssemos',
#  'fossem',
#  'for',
#  'formos',
#  'forem',
#  'serei',
#  'será',
#  'seremos',
#  'serão',
#  'seria',
#  'seríamos',
#  'seriam',
#  'tenho',
#  'tem',
#  'temos',
#  'tém',
#  'tinha',
#  'tínhamos',
#  'tinham',
#  'tive',
#  'teve',
#  'tivemos',
#  'tiveram',
#  'tivera',
#  'tivéramos',
#  'tenha',
#  'tenhamos',
#  'tenham',
#  'tivesse',
#  'tivéssemos',
#  'tivessem',
#  'tiver',
#  'tivermos',
#  'tiverem',
#  'terei',
#  'terá',
#  'teremos',
#  'terão',
#  'teria',
#  'teríamos',
#  'teriam']

# %%
#criando uma lista de palavra sem stopword e pontuações
keywords = [palavra for palavra in lista_de_palavras if not palavra in stop_words and not palavra in pontuacao]
keywords
# Out:
# ['email',
#  'josé',
#  'paes',
#  'costa',
#  'neto',
#  'jnetopc',
#  '@',
#  'gmail.com',
#  'telefones',
#  '79',
#  '981311901',
#  '79',
#  '999175999',
#  'cientista',
#  'dados',
#  'formação',
#  'matemática',
#  'aplicada',
#  'experiência',
#  'área',
#  'endereço',
#  'linkedin',
#  'machine',
#  'learning',
#  '.',
#  'aracaju/se',
#  'linkedin',
#  'objetivo',
#  'atuar',
#  'cientista',
#  'dados',
#  'https',
#  '//www.linkedin.com/in/josé-paes-da-',
#  'costa-neto',
#  'github',
#  'https',
#  '//github.com/josepaesneto',
#  'experiência',
#  'analista',
#  'sistemas',
#  'rede',
#  'cuidar',
#  'responsável',
#  'implementação',
#  'suporte',
#  'sistema',
#  'e-sus',
#  'banco',
#  'dados',
#  'durante',
#  'estado',
#  'paraíba',
#  'caravana',
#  'rede',
#  'cuidar',
#  'estado',
#  'paraíba',
#  '.',
#  '07.2019',
#  '-',
#  'voluntario',
#  'auxiliar',
#  'lotado',
#  'setor',
#  'ti',
#  'responsável',
#  'rede',
#  'banco',
#  'dados',
#  '.',
#  'realizou',
#  'projeto',
#  'cartório',
#  'construção',
#  'banco',
#  'dados',
#  'registros',
#  'imóveis',
#  'protestos',
#  'títulos',
#  'primeiro',
#  'oficio',
#  'socorro',
#  'cadastrados',
#  'empresa',
#  'forma',
#  'física',
#  '.',
#  '08.2014',
#  '–',
#  '11.2014',
#  'formação',
#  'ufpb',
#  '–',
#  'universidade',
#  'federal',
#  'mestrado',
#  'modelagem',
#  'computacional',
#  'paraíba',
#  'pb',
#  'período',
#  '2017',
#  '–',
#  'interrompido',
#  'ufs',
#  '–',
#  'universidade',
#  'federal',
#  'sergipe',
#  'matemática',
#  'aplicada',
#  'computacional',
#  'período',
#  '2013',
#  '–',
#  '2017',
#  'idiomas',
#  'projetos',
#  'extensões',
#  'português',
#  '▪',
#  'iniciação',
#  'científica',
#  'pibic',
#  '–',
#  'projeto',
#  'construção',
#  'imagens',
#  'panorâmicas',
#  'utilizando',
#  'inglês',
#  'machine',
#  'learning',
#  '.',
#  'espanhol',
#  'treinamentos',
#  'informática',
#  '▪',
#  'imersão',
#  'flai',
#  'projetos',
#  'data',
#  'science',
#  '–',
#  'flai',
#  'inteligência',
#  'artificial',
#  '▪',
#  'python',
#  'avançado',
#  '▪',
#  'jornada',
#  'python',
#  '–',
#  'hashtag',
#  'treinamentos',
#  '▪',
#  'jornada',
#  'excel',
#  '–',
#  'hashtag',
#  'treinamentos',
#  '▪',
#  'excel',
#  'avançado',
#  '▪',
#  'dashboards',
#  'power',
#  'bi',
#  '–',
#  'mamba',
#  'treinamentos',
#  '.',
#  '▪',
#  'power',
#  'bi',
#  'intermediário',
#  '▪',
#  'machine',
#  'learning',
#  'intermediário',
#  '▪',
#  'estatística',
#  'avançada',
#  '▪',
#  'big',
#  'data',
#  'intermediário',
#  '▪',
#  'r',
#  'intermediário',
#  '▪',
#  'sql',
#  'intermediário']

# %%
#numero de palavras das reviews
len(keywords)
# Out:
# 195

# %%
# concatenar as palavras
textocv = " ".join(s for s in keywords)
textocv
# Out:
# 'email josé paes costa neto jnetopc @ gmail.com telefones 79 981311901 79 999175999 cientista dados formação matemática aplicada experiência área endereço linkedin machine learning . aracaju/se linkedin objetivo atuar cientista dados https //www.linkedin.com/in/josé-paes-da- costa-neto github https //github.com/josepaesneto experiência analista sistemas rede cuidar responsável implementação suporte sistema e-sus banco dados durante estado paraíba caravana rede cuidar estado paraíba . 07.2019 - voluntario auxiliar lotado setor ti responsável rede banco dados . realizou projeto cartório construção banco dados registros imóveis protestos títulos primeiro oficio socorro cadastrados empresa forma física . 08.2014 – 11.2014 formação ufpb – universidade federal mestrado modelagem computacional paraíba pb período 2017 – interrompido ufs – universidade federal sergipe matemática aplicada computacional período 2013 – 2017 idiomas projetos extensões português ▪ iniciação científica pibic – projeto construção imagens panorâmicas utilizando inglês machine learning . espanhol treinamentos informática ▪ imersão flai projetos data science – flai inteligência artificial ▪ python avançado ▪ jornada python – hashtag treinamentos ▪ jornada excel – hashtag treinamentos ▪ excel avançado ▪ dashboards power bi – mamba treinamentos . ▪ power bi intermediário ▪ machine learning intermediário ▪ estatística avançada ▪ big data intermediário ▪ r intermediário ▪ sql intermediário'

# %% [markdown]
# ---
# ### **WordCloud - Nuvem de Palavras**

# %%
# gerar uma wordcloud

from wordcloud import WordCloud

wordcloud = WordCloud(background_color = '#0f54c9', 
                      max_font_size = 150, 
                      width = 1280, 
                      height = 720, 
                      colormap= 'Blues').generate(textocv) 

# mostrar a imagem final
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
wordcloud.to_file("wordcloud.png")
plt.show()

# %% [markdown]
# ### Criando uma função para criar uma wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def NuvemDePalavras(cv, salvar = True):
    '''
    cv: caminho de um arquivo PDF 
    '''
    arquivoPDF = pdfplumber.open(cv)
    primeira_pagina = arquivoPDF.pages[0]  #lê apenas a primeira página
    textoCRU = primeira_pagina.extract_text()

    lista_de_palavras = nltk.tokenize.word_tokenize(textoCRU)  # transforma o texto cru em uma lista de termos
    lista_de_palavras = [palavra.lower() for palavra in lista_de_palavras]  # deixando tudo minusculo

    keywords = [palavra for palavra in lista_de_palavras if not palavra in stop_words and not palavra in pontuacao]  # tira as pontuacoes e stopwords 
    textocv = " ".join(s for s in keywords)  # junta tudo em um texto só novamente. 


    wordcloud = WordCloud(background_color = '#0f54c9', 
                          max_font_size = 150, 
                          width = 1280, 
                          height = 720, 
                          colormap= 'Blues').generate(textocv) 
 
    # mostrar a imagem final
    fig, ax = plt.subplots(figsize=(16, 9))
    ax.imshow(wordcloud)
    ax.set_axis_off()
    plt.imshow(wordcloud)

    if salvar:
        wordcloud.to_file("wordcloud.png")

    plt.show()

# %%
NuvemDePalavras('CV.pdf')

# %% [markdown]
# ### Math com as vagas de emprego

# %%
import pandas as pd

vagas = pd.read_excel('vagas.xlsx', sheet_name = None)

# %%
n_vagas = len(vagas.keys())
nome_vagas = list(vagas.keys())
n_vagas
nome_vagas
# Out:
# ['ds_senior', 'ds_junior', 'eng_dados', 'marketing']

# %%
# transformando a saida numa lista de dataframes (cada dataframe representa uma vaga)
vagas = [vagas[nome_vagas[i]] for i in range(n_vagas)]

# %%
vaga1 = vagas[1]
vaga1
# Out:
#      palavras-chave  pesos
# 0            python      2
# 1  machine learning      2
# 2  análise de dados      2
# 3         projetos       1
# 4              sql       1

# %%
# Clear Sale Data Science junior
import numpy as np

limite = 5
  
pesos = list(vaga1['pesos'])
palavras_chaves = list(vaga1['palavras-chave'])
pmax = np.sum(np.array(pesos) * limite)
print(pmax)
# Out:
# 40

# %%
# contando as palavras chaves que ocorrem no CV

cont = [textocv.count(pc) for pc in palavras_chaves]
cont
# Out:
# [2, 3, 0, 2, 1]

# %%
# limitar pelo threshold
def aux(x):
    return x if x <= limite else limite

cont = [aux(i) for i in cont]
cont
# Out:
# [2, 3, 0, 2, 1]

# %%
score = ((np.array(cont) * pesos).sum()/pmax).round(4)
score
# Out:
# 0.325

# %% [markdown]
# ### Criando tudo acima numa unica função

# %%
# função entrada: CV saida, vaga - saida: score

pontuacao = ['(', ')', ';', ':', '[', ']', ',']
stop_words = nltk.corpus.stopwords.words('portuguese')

def MatchCV(cv, vaga, limite = 5):
    '''
    cv: caminho de um arquivo PDF
    vaga: dataset de palavras-chave e pesos
    '''

    arquivoPDF = pdfplumber.open(cv)
    primeira_pagina = arquivoPDF.pages[0]  #lê apenas a primeira página
    textoCRU = primeira_pagina.extract_text()

    lista_de_palavras = nltk.tokenize.word_tokenize(textoCRU)  # transforma o texto cru em uma lista de termos
    lista_de_palavras = [palavra.lower() for palavra in lista_de_palavras]  # deixando tudo minusculo

    keywords = [palavra for palavra in lista_de_palavras if not palavra in stop_words and not palavra in pontuacao]  # tira as pontuacoes e stopwords 
    textocv = " ".join(s for s in keywords)  # junta tudo em um texto só novamente. 

    pesos = list(vaga['pesos'])
    palavras_chaves = list(vaga['palavras-chave'])

    cont = [textocv.count(pc) for pc in palavras_chaves]  # conta quantas vezes cada termo da vaga aparece no texto do cv

    def aux(x, limite):
        return x if x <= limite else limite

    cont = [aux(i, limite) for i in cont]   # coloca o limite na contagem de palavras

    pmax = np.sum(np.array(pesos) * limite) 

    score = ((np.array(cont) * pesos).sum()/pmax).round(4)

    return score

# %%
MatchCV('CV.pdf', vagas[2])
# Out:
# 0.0667

# %% [markdown]
# ### Caso deseje avaliar n-candidatos

# %%
lista_de_vagas = vagas

lista_de_cvs = ['cv1.pdf',
                'cv2.pdf',
                'cv3.pdf',
                'cv4.pdf',
                ]
lista_de_vagas[0]
# Lista de Listas, cada lista interna é score de uma pessoa nas vagas
pessoas = [[MatchCV(cv, vaga) for vaga in lista_de_vagas] for cv in lista_de_cvs]
pessoas
# filtro para pegar apenas os nomes das pessoas na lista de caminhos
nomes = [cv.split('/')[-1].split('.')[0] for cv in lista_de_cvs]
# Conjunto de dados comos matches das pessoas com as vagas
matchs = pd.DataFrame(pessoas, columns = nome_vagas, index = nomes)

# %%
matchs.sort_values(by = 'marketing', ascending = False)
